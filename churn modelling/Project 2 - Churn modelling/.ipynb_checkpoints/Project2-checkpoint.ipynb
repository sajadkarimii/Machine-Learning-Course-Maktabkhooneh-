# %% [markdown]
# <img src="https://webna.ir/wp-content/uploads/2018/08/%D9%85%DA%A9%D8%AA%D8%A8-%D8%AE%D9%88%D9%86%D9%87.png" width=50% />

# %% [markdown]
# <div class="alert alert-block alert-success">
#     <h1 align="center">Machine Learning in Python</h1>
#     <h3 align="center">Project2</h3>
# </div>

# %% [markdown]
# <img src = "https://slitayem.github.io/img/blog/2020-08-04/churn.png" width=50%>

# %% [markdown]
# ## Importing the libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import OneHotEncoder,StandardScaler

# %% [markdown]
# ## Load and Prepare Data

# %%
data = pd.read_csv("Churn.csv")

# %%
data.head()
# Out:
#    RowNumber  CustomerId   Surname  CreditScore Geography  Gender  Age  \
# 0          1    15634602  Hargrave          619    France  Female   42
# 1          2    15647311      Hill          608     Spain  Female   41
# 2          3    15619304      Onio          502    France  Female   42
# 3          4    15701354      Boni          699    France  Female   39
# 4          5    15737888  Mitchell          850     Spain  Female   43
#
#    Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0       2       0.00              1          1               1
# 1       1   83807.86              1          0               1
# 2       8  159660.80              3          1               0
# 3       1       0.00              2          0               0
# 4       2  125510.82              1          1               1
#
#    EstimatedSalary  Exited
# 0        101348.88       1
# 1        112542.58       0
# 2        113931.57       1
# 3         93826.63       0
# ...

# %%
data.tail()
# Out:
#       RowNumber  CustomerId    Surname  CreditScore Geography  Gender  Age  \
# 9995       9996    15606229   Obijiaku          771    France    Male   39
# 9996       9997    15569892  Johnstone          516    France    Male   35
# 9997       9998    15584532        Liu          709    France  Female   36
# 9998       9999    15682355  Sabbatini          772   Germany    Male   42
# 9999      10000    15628319     Walker          792    France  Female   28
#
#       Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 9995       5       0.00              2          1               0
# 9996      10   57369.61              1          1               1
# 9997       7       0.00              1          0               1
# 9998       3   75075.31              2          1               0
# 9999       4  130142.79              1          1               0
#
#       EstimatedSalary  Exited
# 9995         96270.64       0
# 9996        101699.77       0
# ...

# %% [markdown]
# ## EDA

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   RowNumber        10000 non-null  int64
#  1   CustomerId       10000 non-null  int64
#  2   Surname          10000 non-null  object
#  3   CreditScore      10000 non-null  int64
#  4   Geography        10000 non-null  object
#  5   Gender           10000 non-null  object
#  6   Age              10000 non-null  int64
#  7   Tenure           10000 non-null  int64
#  8   Balance          10000 non-null  float64
#  9   NumOfProducts    10000 non-null  int64
#  10  HasCrCard        10000 non-null  int64
#  11  IsActiveMember   10000 non-null  int64
#  12  EstimatedSalary  10000 non-null  float64
#  13  Exited           10000 non-null  int64
# dtypes: float64(2), int64(9), object(3)
# memory usage: 1.1+ MB

# %%
data.describe()
# Out:
#          RowNumber    CustomerId   CreditScore           Age        Tenure  \
# count  10000.00000  1.000000e+04  10000.000000  10000.000000  10000.000000
# mean    5000.50000  1.569094e+07    650.528800     38.921800      5.012800
# std     2886.89568  7.193619e+04     96.653299     10.487806      2.892174
# min        1.00000  1.556570e+07    350.000000     18.000000      0.000000
# 25%     2500.75000  1.562853e+07    584.000000     32.000000      3.000000
# 50%     5000.50000  1.569074e+07    652.000000     37.000000      5.000000
# 75%     7500.25000  1.575323e+07    718.000000     44.000000      7.000000
# max    10000.00000  1.581569e+07    850.000000     92.000000     10.000000
#
#              Balance  NumOfProducts    HasCrCard  IsActiveMember  \
# count   10000.000000   10000.000000  10000.00000    10000.000000
# mean    76485.889288       1.530200      0.70550        0.515100
# std     62397.405202       0.581654      0.45584        0.499797
# ...

# %%
pd.crosstab(data["Gender"],data["Exited"],normalize="index")
# Out:
# Exited         0         1
# Gender
# Female  0.749285  0.250715
# Male    0.835441  0.164559

# %%
pd.crosstab(data["IsActiveMember"],data["Exited"],normalize="index")
# Out:
# Exited                 0         1
# IsActiveMember
# 0               0.731491  0.268509
# 1               0.857309  0.142691

# %%
pd.crosstab(data["HasCrCard"],data["Exited"],normalize="index")
# Out:
# Exited            0         1
# HasCrCard
# 0          0.791851  0.208149
# 1          0.798157  0.201843

# %% [markdown]
# ## Data Preprocessing

# %%
data.isna().sum()
# Out:
# RowNumber          0
# CustomerId         0
# Surname            0
# CreditScore        0
# Geography          0
# Gender             0
# Age                0
# Tenure             0
# Balance            0
# NumOfProducts      0
# HasCrCard          0
# IsActiveMember     0
# EstimatedSalary    0
# Exited             0
# dtype: int64

# %%
data.dtypes
# Out:
# RowNumber            int64
# CustomerId           int64
# Surname             object
# CreditScore          int64
# Geography           object
# Gender              object
# Age                  int64
# Tenure               int64
# Balance            float64
# NumOfProducts        int64
# HasCrCard            int64
# IsActiveMember       int64
# EstimatedSalary    float64
# Exited               int64
# dtype: object

# %%
data.max()
# Out:
# RowNumber              10000
# CustomerId          15815690
# Surname               Zuyeva
# CreditScore              850
# Geography              Spain
# Gender                  Male
# Age                       92
# Tenure                    10
# Balance            250898.09
# NumOfProducts              4
# HasCrCard                  1
# IsActiveMember             1
# EstimatedSalary    199992.48
# Exited                     1
# dtype: object

# %%
data[['HasCrCard','IsActiveMember','Exited']] = data[['HasCrCard','IsActiveMember','Exited']].astype(bool)

# %%
data[['Age','Tenure','NumOfProducts']] = data[['Age','Tenure','NumOfProducts']].astype("int8")

# %%
data[['RowNumber','CreditScore']] = data[['RowNumber','CreditScore']].astype("int16")

# %%
data['CustomerId'] = data['CustomerId'].astype("int32")

# %%
data[['Balance','EstimatedSalary']] = data[['Balance','EstimatedSalary']].astype("float32")

# %%
data.dtypes
# Out:
# RowNumber            int16
# CustomerId           int32
# Surname             object
# CreditScore          int16
# Geography           object
# Gender              object
# Age                   int8
# Tenure                int8
# Balance            float32
# NumOfProducts         int8
# HasCrCard             bool
# IsActiveMember        bool
# EstimatedSalary    float32
# Exited                bool
# dtype: object

# %%
data["Gender"].replace({"Female" : 0 , "Male" : 1},inplace=True)
data["Gender"] = data["Gender"].astype(bool)

# %%
encoder = OneHotEncoder(handle_unknown="ignore",sparse_output=False).set_output(transform="pandas")

# %%
encoded = encoder.fit_transform(data[["Geography"]])

# %%
data = pd.concat([data,encoded.astype(bool)],axis=1)

# %% [markdown]
# ## Strorytelling - Visualization

# %%
counts = data["Exited"].value_counts().sort_index()
plt.bar(counts.index, counts.values)
plt.xlabel("Exited")
plt.ylabel("Count")
plt.show()

# %%
means = data.groupby("Geography")["Exited"].mean().sort_values()
plt.bar(means.index, means.values)
plt.xlabel("Geography")
plt.ylabel("Exited")
plt.show()

# %%
means = data.groupby("Tenure")["Exited"].mean().sort_values()
plt.bar(means.index, means.values)
plt.xlabel("Tenure")
plt.ylabel("Exited")
plt.show()

# %%
means = data.groupby("NumOfProducts")["Exited"].mean().sort_values()
plt.bar(means.index, means.values)
plt.xlabel("NumOfProducts")
plt.ylabel("Exited")
plt.show()

# %%
means = data.groupby("CreditScore")["Exited"].mean()
plt.plot(means.index, means.values)
plt.xlabel("CreditScore")
plt.ylabel("Exited")
plt.show()

# %%
means = data.groupby("Age")["Exited"].mean()
plt.plot(means.index, means.values)
plt.xlabel("Age")
plt.ylabel("Exited")
plt.show()

# %%
data
# Out:
#       RowNumber  CustomerId    Surname  CreditScore Geography  Gender  Age  \
# 0             1    15634602   Hargrave          619    France   False   42
# 1             2    15647311       Hill          608     Spain   False   41
# 2             3    15619304       Onio          502    France   False   42
# 3             4    15701354       Boni          699    France   False   39
# 4             5    15737888   Mitchell          850     Spain   False   43
# ...         ...         ...        ...          ...       ...     ...  ...
# 9995       9996    15606229   Obijiaku          771    France    True   39
# 9996       9997    15569892  Johnstone          516    France    True   35
# 9997       9998    15584532        Liu          709    France   False   36
# 9998       9999    15682355  Sabbatini          772   Germany    True   42
# 9999      10000    15628319     Walker          792    France   False   28
#
# ...

# %%
plt.figure(figsize=(10,10))
sns.heatmap(data.drop(["Surname","RowNumber","Geography"],axis=1).corr(),annot=True)
# Out:
# <Axes: >

# %% [markdown]
# ## Prepare Data for Machine learning

# %%
scaler = StandardScaler()
data[data.drop(columns=["Geography","Surname","Exited"]).columns] = scaler.fit_transform(data.drop(columns=["Geography","Surname","Exited"]))

# %% [markdown]
# ## Train your model

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split , GridSearchCV
from sklearn.metrics import classification_report,confusion_matrix,ConfusionMatrixDisplay

# %%
X_train , X_test , Y_train , Y_test = train_test_split(data.drop(columns=["Geography","Surname","Exited"]),data["Exited"],test_size=.1,random_state=42)

# %%
rfc = RandomForestClassifier()

# %%
param={"criterion":["gini","entropy"],"class_weight":[None,{True:4,False:1},{True:3,False:1}]}

# %%
gsc = GridSearchCV(rfc,param_grid=param,scoring="f1",cv=5)

# %%
gsc.fit(X_train,Y_train)
# Out:
# GridSearchCV(cv=5, estimator=RandomForestClassifier(),
#              param_grid={'class_weight': [None, {False: 1, True: 4},
#                                           {False: 1, True: 3}],
#                          'criterion': ['gini', 'entropy']},
#              scoring='f1')

# %%
gsc.best_score_
# Out:
# 0.5743452597911617

# %%
gsc.best_params_
# Out:
# {'class_weight': None, 'criterion': 'gini'}

# %%
rfc = RandomForestClassifier(criterion='entropy').fit(X_train,Y_train)

# %%
rfc.score(X_train,Y_train)
# Out:
# 1.0

# %%
from pycaret.classification import *

# %%
data
# Out:
#       RowNumber  CustomerId    Surname  CreditScore Geography    Gender  \
# 0     -1.731878   -0.783213   Hargrave    -0.326221    France -1.095988
# 1     -1.731531   -0.606534       Hill    -0.440036     Spain -1.095988
# 2     -1.731185   -0.995885       Onio    -1.536794    France -1.095988
# 3     -1.730838    0.144767       Boni     0.501521    France -1.095988
# 4     -1.730492    0.652659   Mitchell     2.063884     Spain -1.095988
# ...         ...         ...        ...          ...       ...       ...
# 9995   1.730492   -1.177652   Obijiaku     1.246488    France  0.912419
# 9996   1.730838   -1.682806  Johnstone    -1.391939    France  0.912419
# 9997   1.731185   -1.479282        Liu     0.604988    France -1.095988
# 9998   1.731531   -0.119356  Sabbatini     1.256835   Germany  0.912419
# 9999   1.731878   -0.870559     Walker     1.463771    France -1.095988
#
#            Age    Tenure   Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# ...

# %%
cl = setup(data=data.drop(["Surname","Geography"],axis=1),target="Exited")
# Out:
# <style type="text/css">
# #T_c8aa4_row8_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_c8aa4">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_c8aa4_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_c8aa4_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c8aa4_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_c8aa4_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_c8aa4_row0_col1" class="data row0 col1" >3078</td>
#     </tr>
#     <tr>
#       <th id="T_c8aa4_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_c8aa4_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_c8aa4_row1_col1" class="data row1 col1" >Exited</td>
#     </tr>
#     <tr>
#       <th id="T_c8aa4_level0_row2" class="row_heading level0 row2" >2</th>
# ...

# %%
best_model = compare_models()
# Out:
# <style type="text/css">
# #T_92318 th {
#   text-align: left;
# }
# ...

# %% [markdown]
# ## Test the model and show the metrics

# %%
print(classification_report(Y_test,rfc.predict(X_test)))
# Out:
#               precision    recall  f1-score   support
#
#        False       0.88      0.97      0.92       809
#         True       0.75      0.45      0.56       191
#
#     accuracy                           0.87      1000
#    macro avg       0.82      0.71      0.74      1000
# weighted avg       0.86      0.87      0.85      1000

# %%
ConfusionMatrixDisplay(confusion_matrix = confusion_matrix(Y_test,rfc.predict(X_test)), display_labels = [0, 1]).plot()

# %% [markdown]
# ## Save your final model

# %%
from pycaret.classification import save_model

# %%
save_model(rfc, 'my_best_model')
# Out:
# Transformation Pipeline and Model Successfully Saved
# (Pipeline(memory=Memory(location=None),
#           steps=[('numerical_imputer',
#                   TransformerWrapper(exclude=None,
#                                      include=['RowNumber', 'CustomerId',
#                                               'CreditScore', 'Gender', 'Age',
#                                               'Tenure', 'Balance',
#                                               'NumOfProducts', 'HasCrCard',
#                                               'IsActiveMember',
#                                               'EstimatedSalary',
#                                               'Geography_France',
#                                               'Geography_Germany',
#                                               'Geography_Spain'],
#                                      transformer=SimpleImputer(add_indicator=False,
#                                                                cop...
# ...

# %% [markdown]
# ## Send us the Result (Maktabkhoone)
